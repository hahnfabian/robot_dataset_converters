# %%
# requirements
# addict
# datsets
# modelscope

# %%
from modelscope.msdatasets import MsDataset

# %%
info = MsDataset.load(
    'X-Humanoid/RoboMIND2.0-Franka-Part-1',
    dataset_info_only=True
)

print(info)
# Out:
# {'default': ['test']}

# %%
ds = MsDataset.load(
    'X-Humanoid/RoboMIND2.0-Franka-Part-1',
    split='test',
    use_streaming=True
)
# Out:
# 'The read operation timed out' thrown while requesting GET https://www.modelscope.cn/datasets/X-Humanoid/RoboMIND2.0-Franka-Part-1/resolve/master/data/franka/attach_green_and_red_cubes_to_black_cube/success_episodes/0606_171640_test/data/trajectory.hdf5
# Retrying in 1s [Retry 1/5].
